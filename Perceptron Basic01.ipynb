# %%
from sklearn.datasets import make_classification
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
plt.scatter(X[0:,0],X[0:,1],c=y,cmap='winter')

# %%
X= np.insert(X,0,1,axis=1)

# %%
weights=np.ones(X.shape[1])

# %%
weights
# Out:
# array([1., 1., 1.])

# %%
X[1]
# Out:
# array([ 1.        , -0.24882029, -0.73115232])

# %%
y_hat=step(np.dot(X[1],weights))

# %%
y_hat
# Out:
# 1

# %%
def step(n):
    return 1 if n>0 else 0

# %%
       
def perceptron(X,y):
    
    X= np.insert(X,0,1,axis=1)
    weights=np.ones(X.shape[1])
    lr=0.1
    for i in range(10000):
        j=np.random.randint(0,1000)
        y_hat=step(np.dot(X[j],weights))
        weights=weights+(lr*(y[j]-y_hat)*X[j])
        
    return weights[0],weights[1:]

# %%
def perceptron(X,y):
    
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1
    
    for i in range(10000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j]-y_hat)*X[j]
        
    return weights[0],weights[1:]

# %%
intercept,coeff=perceptron(X,y)

# %%
intercept
# Out:
# 1.0

# %%
coeff
# Out:
# array([1.28155018, 0.02909168])

# %%
m=-(coeff[0]/coeff[1])
b= intercept

# %%
x_input=np.linspace(-1.5,1.5,100)
y_output=m*x_input+b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_output,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,3)
# Out:
# (-3.0, 3.0)
